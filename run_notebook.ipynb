# %%
# %run evals_pytorch.py
# Out:
# Generating data...
# Done.
# Starting training...
# Initializing and training URNNs for one timestep...
# Network __init__ over. Number of trainable params= 7169
# Training network  ap_urnn ... timesteps= 200
# Starting training for ap_urnn
# NumEpochs:  15 |BatchSize:  50 |NumBatches:   800
#
# Epoch Starting: 0
#
# Epoch:   0 |Batch:   0 |TotalExamples:    50 |BatchLoss:   2.1337
# Epoch:   0 |Batch:  10 |TotalExamples:   550 |BatchLoss:   0.1538
# Epoch:   0 |Batch:  20 |TotalExamples:  1050 |BatchLoss:   0.2263
# Epoch:   0 |Batch:  30 |TotalExamples:  1550 |BatchLoss:   0.1995
# Epoch:   0 |Batch:  40 |TotalExamples:  2050 |BatchLoss:   0.1998
# Epoch:   0 |Batch:  50 |TotalExamples:  2550 |BatchLoss:   0.1178
# Epoch:   0 |Batch:  60 |TotalExamples:  3050 |BatchLoss:   0.1535
# Epoch:   0 |Batch:  70 |TotalExamples:  3550 |BatchLoss:   0.1122
# Epoch:   0 |Batch:  80 |TotalExamples:  4050 |BatchLoss:   0.1584
# Epoch:   0 |Batch:  90 |TotalExamples:  4550 |BatchLoss:   0.1263
# ...
